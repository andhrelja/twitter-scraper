# %%
from twitter_scraper import settings
from twitter_scraper.graph.nodes import NODE_DTYPE

import matplotlib.pyplot as plt
import pandas as pd

nodes_df = pd.read_csv(settings.NODES_CSV, dtype=NODE_DTYPE)

# %%
nodes_df.head()
# Out:
#    user_id  total_tweets  user_id_str  ... clean_location   out_d    in_d
# 0     7331            37         7331  ...       Hrvatska  1104.0   542.0
# 1    11705            10        11705  ...       Hrvatska   234.0   429.0
# 2    12667           115        12667  ...       Hrvatska  2683.0   801.0
# 3   664493             4       664493  ...       Hrvatska   135.0   257.0
# 4   680383          1865       680383  ...       Hrvatska  1148.0  4966.0
#
# [5 rows x 28 columns]
