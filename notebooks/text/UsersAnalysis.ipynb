# %% [markdown]
# # Cleaning The Data
#
# When dealing with numerical data, data cleaning often involves removing null values and duplicate data, dealing with outliers, etc. With text data, there are some common data cleaning techniques, which are also known as text pre-processing techniques.
#
# With text data, this cleaning process can go on forever. There's always an exception to every cleaning step. So, we're going to follow the MVP (minimum viable product) approach - start simple and iterate. Here are a bunch of things you can do to clean your data. We're going to execute just the common cleaning steps here and the rest can be done at a later point to improve our results.
#
# Common data cleaning steps on all text:
#
# - Make text all lower case
# - Remove punctuation
# - Remove numerical values
# - Remove common non-sensical text (/n)
# - Tokenize text
# - Remove stop words
#
# More data cleaning steps after tokenization:
#
# - Stemming / lemmatization
# - Parts of speech tagging
# - Create bi-grams or tri-grams
# - Deal with typos
# - And more...

# %%
import pandas as pd

from twitter_scraper import settings

USER_COLS = [
    'user_id',
    'screen_name',
    'verified',
    'location'
]

TWEET_COLS = [
    'id',
    'created_at',
    'week',
    'month',
    'user_id',
    'user_mentions',
    'hashtags',
    'langid',
    'full_text',
    'stemmed',
    'clean_stem',
    'retweet_from_user_id',
    'retweet_from_tweet_id',
]

users_df = pd.read_csv(settings.USERS_CSV).drop_duplicates(subset='user_id')
user_idx = users_df[['user_id', 'screen_name']].set_index('user_id').to_dict()['screen_name']

tweets_df = pd.read_csv(settings.TWEETS_CSV.replace('tweets.csv', 'tweets-text-processed.csv'), low_memory=False)
tweets_df['stemmed'] = tweets_df['stemmed'].map(eval)
tweets_df['clean_stem'] = tweets_df['clean_stem'].map(eval)
tweets_df['user_mentions'] = tweets_df['user_mentions'].map(eval)
df = users_df[USER_COLS].merge(tweets_df[TWEET_COLS], on='user_id', validate='1:m')

# %%
# user_tweets_df = df[['screen_name', 'stemmed']].groupby('screen_name').sum()
most_tweeting_users = df.screen_name.value_counts()[:20].index

# %%
import re
import gensim

processing_df = df.loc[df[df.screen_name.isin(most_tweeting_users)].index]
processing_df['stemmed'] = processing_df['stemmed'].transform(lambda x: list(filter(None, x)))

URL_REGEX = r'https?:\/\/[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)'
MENTIONS_REGEX = r'@[A-Za-z0-9-_]+'
RT_MENTIONS_REGEX = r'rt @[A-Za-z0-9-_:]+'
processing_df['full_text_processed'] = processing_df['full_text'].fillna('').transform(str.lower)
processing_df['full_text_processed'] = processing_df['full_text_processed'].transform(lambda x: re.sub(URL_REGEX, '', x))
processing_df['full_text_processed'] = processing_df['full_text_processed'].transform(lambda x: re.sub(RT_MENTIONS_REGEX, '', x))
processing_df['full_text_processed'] = processing_df['full_text_processed'].transform(lambda x: re.sub(MENTIONS_REGEX, '', x))
processing_df['full_text_processed'] = processing_df['full_text_processed'].transform(gensim.utils.simple_preprocess)
processing_df['full_text_processed'] = processing_df['full_text_processed'].transform(lambda x: [y for y in x if y not in stop_words])

data_words = processing_df['full_text_processed'].tolist()
bigrams = gensim.models.Phrases(
    sentences=data_words,
    min_count=5,
    threshold=100
)

bigram_model = bigrams.freeze()

trigrams = gensim.models.Phrases(
    sentences=bigrams[data_words],
    min_count=5,
    threshold=100
)

# %%
print(list(trigrams[bigrams[data_words]])[:50])
# Out:
# ['big_tech', 'dell_esercito', 'dell_esercito_ucraino', 'john_ioannidis', 'anthony_fauci', 'check_out', 'quello_che', 'julian_assange', 'war_crimes', 'more_than', 'high_representative', 'foreign_affairs', 'school_closures', 'con_la', 'german_chancellor', 'th_century', 'natural_gas', 'la_verità', 'contro_la', 'ursula_von', 'der_leyen', 'ursula_von_der_leyen', 'liz_truss', 'ha_fatto', 'chi_ha', 'detto_che', 'vladimir_putin', 'gli_usa', 'sempre_più', 'nancy_pelosi', 'makes_sense', 'cold_war', 'il_ministro', 'degli_esteri', 'dell_ucraina', 'non_ci', 'investigation_into', 'covid_vaccines', 'european_union', 'please_unroll', 'climate_change', 'nord_stream', 'talking_about', 'so_much', 'hunter_biden', 'joe_biden', 'white_house', 'una_nuova', 'alex_jones', 'last_night']

# %%
processing_df['bigrams'] = processing_df['full_text_processed'].transform(lambda x: bigram_mod[x])
processing_df['trigrams'] = processing_df['full_text_processed'].transform(lambda x: trigram_mod[x])

# %%
# %env CUDA_VISIBLE_DEVICES=2
import classla
import stanza

from twitter_scraper.utils import fileio

stop_words_eng = fileio.read_content(settings.STOP_WORDS_ENG, 'json')
stop_words_hrv = fileio.read_content(settings.STOP_WORDS_HRV, 'json')
# Because of the way our dataset is limited, we are assuming
# we can allow to concatenate english and croatian stop words
stop_words = stop_words_eng + stop_words_hrv 

nlps = {
    'en': stanza.Pipeline('en', use_gpu=settings.CLASSLA_USE_GPU, logging_level='ERROR'),
    'hr': classla.Pipeline('hr', use_gpu=settings.CLASSLA_USE_GPU, logging_level='ERROR'),
    'sr': classla.Pipeline('sr', use_gpu=settings.CLASSLA_USE_GPU, logging_level='ERROR'),
    'sl': classla.Pipeline('sl', use_gpu=settings.CLASSLA_USE_GPU, logging_level='ERROR')
}
nlps['bs'] = nlps['hr']
# Out:
# env: CUDA_VISIBLE_DEVICES=2
# [WARNING] 2022-11-07 07:27:20 discord.client - PyNaCl is not installed, voice will NOT be supported

# %%
def get_lemmatized_text(row, upos=['NOUN', 'ADJ']):
    if row['langid'] in ('hr', 'bs', 'sr', 'sl'):
        nlp = nlps[row['langid']]
    else:
        nlp = nlps['en']
        
    if not row['bigrams']: 
        return []
    
    doc = nlp(" ".join(row['bigrams']))
    return [word.lemma for sentence in doc.sentences for word in sentence.words if word.upos in upos]

# processing_df.iloc[0]
# processing_df['trigram_stems'] = processing_df.apply(get_lemmatized_text, axis=1)

# %%
import pandas as pd
import gensim
import datetime as dt
from twitter_scraper import settings

processing_df = pd.read_csv(settings.TWEETS_CSV.replace('tweets.csv', 'processing_df.csv'), low_memory=False)
processing_df['created_at'] = pd.to_datetime(processing_df['created_at'])
processing_df = processing_df.loc[
    (processing_df['screen_name'] == 'DNEVNIKhr')
    & (processing_df['created_at'] > dt.datetime(2022, 10, 1, 0, 0, 0, tzinfo=dt.timezone.utc))
]
processing_df['bigrams'] = processing_df['bigrams'].map(eval)
processing_df['bigram_stems'] = processing_df.apply(get_lemmatized_text, axis=1)
processing_df
# Out:
#         user_id screen_name  verified             location  \
# 82831  80316128   DNEVNIKhr      True  Republic of Croatia
# 82832  80316128   DNEVNIKhr      True  Republic of Croatia
# 82833  80316128   DNEVNIKhr      True  Republic of Croatia
# 82834  80316128   DNEVNIKhr      True  Republic of Croatia
# 82835  80316128   DNEVNIKhr      True  Republic of Croatia
# ...         ...         ...       ...                  ...
# 86671  80316128   DNEVNIKhr      True  Republic of Croatia
# 86672  80316128   DNEVNIKhr      True  Republic of Croatia
# 86673  80316128   DNEVNIKhr      True  Republic of Croatia
# 86674  80316128   DNEVNIKhr      True  Republic of Croatia
# 86675  80316128   DNEVNIKhr      True  Republic of Croatia
#
#                         id                created_at     week    month  \
# 82831  1581952890016387073 2022-10-17 10:18:54+00:00  2022-42  2022-10
# 82832  1581952649544761344 2022-10-17 10:17:57+00:00  2022-42  2022-10
# 82833  1581942847162314753 2022-10-17 09:39:00+00:00  2022-42  2022-10
# 82834  1581935547991216129 2022-10-17 09:10:00+00:00  2022-42  2022-10
# 82835  1581934034665414656 2022-10-17 09:03:59+00:00  2022-42  2022-10
# ...                    ...                       ...      ...      ...
# 86671  1582627611154550785 2022-10-19 07:00:00+00:00  2022-42  2022-10
# 86672  1582622574957236228 2022-10-19 06:40:00+00:00  2022-42  2022-10
# 86673  1582617541939146753 2022-10-19 06:20:00+00:00  2022-42  2022-10
# 86674  1582612510913359872 2022-10-19 06:00:00+00:00  2022-42  2022-10
# 86675  1582608000258396162 2022-10-19 05:42:05+00:00  2022-42  2022-10
#
#       user_mentions                           hashtags  ...  \
# 82831            []                      ['dnevnikhr']  ...
# 82832  [1288788320]                      ['dnevnikhr']  ...
# 82833            []                      ['dnevnikhr']  ...
# 82834  [1288788320]                      ['dnevnikhr']  ...
# 82835            []                      ['dnevnikhr']  ...
# ...             ...                                ...  ...
# 86671            []           ['dnevnikhr', 'ukraine']  ...
# 86672            []                      ['dnevnikhr']  ...
# 86673            []                      ['dnevnikhr']  ...
# 86674            []                      ['dnevnikhr']  ...
# 86675            []  ['dnevnikhr', 'ukrainerussiawar']  ...
#
#                                                full_text  \
# 82831  "HDZ-ovi dužnosnici pijani mogu napadati, nagu...
# 82832  I dalje oduševljava. #dnevnikhr @golhr\nhttps:...
# 82833  Broj korisnika je u stalnom porastu. #dnevnikh...
# 82834  Policija smirivala situaciju. #dnevnikhr @golh...
# 82835  Oko Otoka Svibovskog. #dnevnikhr\nhttps://t.co...
# ...                                                  ...
# 86671  Hoće li Putinova vlast izdržati vojne poraze? ...
# 86672  Kraljevska obitelj se još uvijek nije oglasila...
# 86673  Oko 300 milijuna eura vrijedan greenfield proj...
# 86674  Država ide u prodaju svojih vila. #dnevnikhr \...
# 86675  Zapovjednik moskovske vojske opisuje vojnu sit...
#
#                                                  stemmed  \
# 82831  ['HDZ', 'dužnosnik', 'pijan', 'napadati', 'nag...
# 82832           ['daleko', 'oduševljavati', 'dnevnikhr']
# 82833  ['broj', 'korisnik', 'stalan', 'porast', 'dnev...
# 82834  ['policija', 'smirivati', 'situacija', 'dnevni...
# 82835               ['otoka', 'svibovskog', 'Dnevnikhr']
# ...                                                  ...
# 86671  ['putin', 'vlast', 'izdržati', 'vojni', 'poraz...
# 86672  ['kraljevski', 'obitelj', 'oglasiti', 'dnevnik...
# 86673  ['milijun', 'euro', 'vrijedan', 'greenfield', ...
# 86674  ['država', 'ići', 'prodaja', 'vila', 'dnevnikhr']
# 86675  ['zapovjednik', 'moskovski', 'vojska', 'opisiv...
#
#                                               clean_stem retweet_from_user_id  \
# 82831  ['HDZ', 'dužnosnik', 'pijan', 'napadati', 'nag...                  NaN
# 82832           ['daleko', 'oduševljavati', 'dnevnikhr']                  NaN
# 82833  ['broj', 'korisnik', 'stalan', 'porast', 'dnev...                  NaN
# 82834  ['policija', 'smirivati', 'situacija', 'dnevni...                  NaN
# 82835               ['otoka', 'svibovskog', 'Dnevnikhr']                  NaN
# ...                                                  ...                  ...
# 86671  ['putin', 'vlast', 'izdržati', 'vojni', 'poraz...                  NaN
# 86672  ['kraljevski', 'obitelj', 'oglasiti', 'dnevnik...                  NaN
# 86673  ['milijun', 'euro', 'vrijedan', 'greenfield', ...                  NaN
# 86674  ['država', 'ići', 'prodaja', 'vila', 'dnevnikhr']                  NaN
# 86675  ['zapovjednik', 'moskovski', 'vojska', 'opisiv...                  NaN
#
#        retweet_from_tweet_id  \
# 82831                    NaN
# 82832                    NaN
# 82833                    NaN
# 82834                    NaN
# 82835                    NaN
# ...                      ...
# 86671                    NaN
# 86672                    NaN
# 86673                    NaN
# 86674                    NaN
# 86675                    NaN
#
#                                      full_text_processed  \
# 82831  ['hdz', 'ovi', 'dužnosnici', 'pijani', 'mogu',...
# 82832              ['dalje', 'oduševljava', 'dnevnikhr']
# 82833  ['broj', 'korisnika', 'je', 'stalnom', 'porast...
# 82834  ['policija', 'smirivala', 'situaciju', 'dnevni...
# 82835        ['oko', 'otoka', 'svibovskog', 'dnevnikhr']
# ...                                                  ...
# 86671  ['hoće', 'li', 'putinova', 'vlast', 'izdržati'...
# 86672  ['kraljevska', 'obitelj', 'se', 'još', 'uvijek...
# 86673  ['oko', 'milijuna', 'eura', 'vrijedan', 'green...
# 86674  ['država', 'ide', 'prodaju', 'svojih', 'vila',...
# 86675  ['zapovjednik', 'moskovske', 'vojske', 'opisuj...
#
#                                                  bigrams  \
# 82831  [hdz, ovi, dužnosnici, pijani, mogu, napadati,...
# 82832                    [dalje, oduševljava, dnevnikhr]
# 82833  [broj, korisnika, je, stalnom, porastu, dnevni...
# 82834        [policija, smirivala, situaciju, dnevnikhr]
# 82835                [oko, otoka, svibovskog, dnevnikhr]
# ...                                                  ...
# 86671  [hoće, li, putinova, vlast, izdržati, vojne, p...
# 86672  [kraljevska, obitelj, se, još, uvijek, nije, o...
# 86673  [oko, milijuna, eura, vrijedan, greenfield, pr...
# 86674    [država, ide, prodaju, svojih, vila, dnevnikhr]
# 86675  [zapovjednik, moskovske, vojske, opisuje, vojn...
#
#                                                 trigrams  \
# 82831  ['hdz', 'ovi', 'dužnosnici', 'pijani', 'mogu',...
# 82832              ['dalje', 'oduševljava', 'dnevnikhr']
# 82833  ['broj', 'korisnika', 'je', 'stalnom', 'porast...
# 82834  ['policija', 'smirivala', 'situaciju', 'dnevni...
# 82835        ['oko', 'otoka', 'svibovskog', 'dnevnikhr']
# ...                                                  ...
# 86671  ['hoće_li', 'putinova', 'vlast', 'izdržati', '...
# 86672  ['kraljevska', 'obitelj', 'se', 'još', 'uvijek...
# 86673  ['oko', 'milijuna_eura', 'vrijedan', 'greenfie...
# 86674  ['država', 'ide', 'prodaju', 'svojih', 'vila',...
# 86675  ['zapovjednik', 'moskovske', 'vojske', 'opisuj...
#
#                                            trigram_stems  \
# 82831  ['HDZ', 'ovaj', 'dužnosnik', 'pijan', 'moći', ...
# 82832           ['daleko', 'oduševljavati', 'dnevnikhr']
# 82833  ['broj', 'korisnik', 'biti', 'stalan', 'porast...
# 82834  ['policija', 'smirivati', 'situacija', 'dnevni...
# 82835        ['oko', 'otoka', 'svibovskog', 'Dnevnikhr']
# ...                                                  ...
# 86671  ['hoćestao', 'putin', 'vlast', 'izdržati', 'vo...
# 86672  ['kraljevski', 'obitelj', 'sebe', 'još', 'uvij...
# 86673  ['oko', 'milijunaheur', 'vrijedan', 'greenfiel...
# 86674  ['država', 'ići', 'prodaja', 'svoj', 'vila', '...
# 86675  ['zapovjednik', 'moskovski', 'vojska', 'opisiv...
#
#                                             bigram_stems
# 82831     [dužnosnik, pijan, vrat, građanin, posljedica]
# 82832                                        [dnevnikhr]
# 82833                   [broj, korisnik, stalan, porast]
# 82834                              [policija, situacija]
# 82835                                                 []
# ...                                                  ...
# 86671                       [putin, vlast, vojni, poraz]
# 86672                              [kraljevski, obitelj]
# 86673     [milijun, euro, vrijedan, greenfield, projekt]
# 86674                            [država, prodaja, vila]
# 86675  [zapovjednik, moskovski, vojska, vojni, situac...
#
# [1265 rows x 21 columns]

# %%
# Create Corpus
texts = processing_df['bigram_stems'].transform(lambda x: list(filter(lambda y: y is not None and y not in stop_words, x))).to_list()
texts = [text for text in texts if len(text) > 0]
# Create Dictionary
id2word = gensim.corpora.Dictionary(texts)
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# Out:
# [INFO] 2022-11-07 07:28:51 gensim.corpora.dictionary - adding document #0 to Dictionary<0 unique tokens: []>
# [INFO] 2022-11-07 07:28:51 gensim.corpora.dictionary - built Dictionary<1792 unique tokens: ['dužnosnik', 'građanin', 'pijan', 'posljedica', 'vrat']...> from 1086 documents (total 3864 corpus positions)
# [INFO] 2022-11-07 07:28:51 gensim.utils - Dictionary lifecycle event {'msg': "built Dictionary<1792 unique tokens: ['dužnosnik', 'građanin', 'pijan', 'posljedica', 'vrat']...> from 1086 documents (total 3864 corpus positions)", 'datetime': '2022-11-07T07:28:51.720318', 'gensim': '4.2.0', 'python': '3.8.10 (default, Jun 22 2022, 20:18:18) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-124-generic-x86_64-with-glibc2.29', 'event': 'created'}

# %%
import matplotlib.pyplot as plt

start=10; limit=16; step=1;
coherence_values = []
model_list = []
for num_topics in range(start, limit, step):
    model = gensim.models.LdaMulticore(corpus=corpus, num_topics=num_topics, id2word=id2word, passes=10)
    model_list.append(model)
    coherencemodel = gensim.models.CoherenceModel(model=model, texts=texts, dictionary=id2word, coherence='c_v')
    coherence_values.append(coherencemodel.get_coherence())

x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
# plt.savefig('Coh_plot_new_10_02_22.png')
plt.show()
# Out:
# [INFO] 2022-11-07 07:28:52 gensim.models.ldamodel - using symmetric alpha at 0.1
# [INFO] 2022-11-07 07:28:52 gensim.models.ldamodel - using symmetric eta at 0.1
# [INFO] 2022-11-07 07:28:52 gensim.models.ldamodel - using serial LDA version on this node
# [INFO] 2022-11-07 07:28:52 gensim.models.ldamulticore - running online LDA training, 10 topics, 10 passes over the supplied corpus of 1086 documents, updating every 94000 documents, evaluating every ~1086 documents, iterating 50x with a convergence threshold of 0.001000
# [INFO] 2022-11-07 07:28:52 gensim.models.ldamulticore - training LDA model using 47 processes
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamulticore - PROGRESS: pass 0, dispatched chunk #0 = documents up to #1086/1086, outstanding queue size 1
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic #9 (0.100): 0.011*"sat" + 0.010*"dinamo" + 0.010*"dan" + 0.010*"mjesec" + 0.010*"ukrajina" + 0.010*"osoba" + 0.008*"TV" + 0.008*"hrvatski" + 0.008*"europa" + 0.008*"nov"
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic #0 (0.100): 0.016*"hrvatski" + 0.012*"velik" + 0.010*"policija" + 0.010*"ozlijediti" + 0.010*"drama" + 0.008*"godina" + 0.006*"vlada" + 0.006*"ministar" + 0.006*"euro" + 0.006*"rast"
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic #3 (0.100): 0.010*"nov" + 0.010*"dnevnik" + 0.008*"prvi" + 0.008*"škola" + 0.006*"razotkrivanje" + 0.006*"dijete" + 0.006*"rezultat" + 0.006*"emisija" + 0.006*"posljedica" + 0.006*"topao"
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic #1 (0.100): 0.019*"godina" + 0.018*"sat" + 0.013*"dnevnik" + 0.011*"TV" + 0.010*"dnevnikučnova" + 0.010*"čovjek" + 0.008*"premijer" + 0.008*"izbor" + 0.006*"prosvjed" + 0.006*"napad"
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic #7 (0.100): 0.017*"sat" + 0.017*"dan" + 0.010*"nov" + 0.008*"velik" + 0.008*"spašavanje" + 0.008*"problem" + 0.008*"vrijeme" + 0.006*"dnevnikučnova" + 0.006*"predsjednik" + 0.006*"ukrajinski"
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic diff=7.499216, rho=1.000000
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - -8.366 per-word bound, 329.8 perplexity estimate based on a held-out corpus of 1086 documents with 3864 words
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamulticore - PROGRESS: pass 1, dispatched chunk #0 = documents up to #1086/1086, outstanding queue size 1
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic #5 (0.100): 0.020*"nov" + 0.011*"dnevnik" + 0.009*"kazna" + 0.009*"moguć" + 0.007*"hrvatski" + 0.007*"eksplozija" + 0.006*"godina" + 0.006*"modrić" + 0.006*"drugi" + 0.005*"glavni"
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic #6 (0.100): 0.019*"nov" + 0.014*"dnevnik" + 0.013*"izbor" + 0.009*"lijep" + 0.009*"istraga" + 0.009*"TV" + 0.007*"bivši" + 0.007*"ponuda" + 0.007*"predsjednik" + 0.007*"okolnost"
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic #4 (0.100): 0.026*"dnevnik" + 0.023*"osoba" + 0.022*"nov" + 0.016*"očevid" + 0.014*"napad" + 0.013*"tijek" + 0.010*"ukrajina" + 0.010*"hrvatski" + 0.008*"putin" + 0.007*"nema"
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - topic #7 (0.100): 0.019*"dan" + 0.018*"sat" + 0.011*"nov" + 0.009*"spektakl" + 0.009*"problem" + 0.009*"vrijeme" + 0.009*"velik" + 0.008*"spašavanje" + 0.007*"cijene-goriva" + 0.007*"dobar"
# [INFO] 2022-11-07 07:28:58 gensim.models.ldamodel - top

# [INFO] 2022-11-07 07:29:00 gensim.models.ldamodel - topic diff=0.008912, rho=0.323711
# [INFO] 2022-11-07 07:29:00 gensim.models.ldamodel - -8.213 per-word bound, 296.7 perplexity estimate based on a held-out corpus of 1086 documents with 3864 words
# [INFO] 2022-11-07 07:29:00 gensim.models.ldamulticore - PROGRESS: pass 9, dispatched chunk #0 = documents up to #1086/1086, outstanding queue size 1
# [INFO] 2022-11-07 07:29:00 gensim.models.ldamodel - topic #7 (0.100): 0.027*"dan" + 0.019*"sat" + 0.013*"spektakl" + 0.011*"vrijeme" + 0.011*"nov" + 0.010*"problem" + 0.009*"velik" + 0.008*"spašavanje" + 0.008*"cijene-goriva" + 0.008*"dobar"
# [INFO] 2022-11-07 07:29:00 gensim.models.ldamodel - topic #5 (0.100): 0.020*"nov" + 0.013*"kazna" + 0.011*"dnevnik" + 0.009*"moguć" + 0.009*"hrvatski" + 0.007*"eksplozija" + 0.007*"godina" + 0.006*"modrić" + 0.006*"drugi" + 0.006*"glavni"
# [INFO] 2022-11-07 07:29:00 gensim.models.ldamodel - topic #1 (0.100): 0.029*"godina" + 0.025*"sat" + 0.018*"čovjek" + 0.017*"dnevnikučnova" + 0.017*"TV" + 0.013*"dnevnik" + 0.009*"premijer" + 0.006*"napad" + 0.006*"dnevnikhra" + 0.006*"informacija"
# [INFO] 2022-11-07 07:29:00 gensim.models.ldamodel - topic #3 (0.100): 0.010*"nov" + 0.010*"dnevnik" + 0.010*"cijena" + 0.008*"prvi" + 0.008*"škola" + 0.008*"emisija" + 0.008*"posljedica" + 0.008*"nedjelja" + 0.006*"rezultat" + 0.006*"razotkrivanje"
# [INFO] 2022-11-07 07:29:00 gensim.models.ldamodel - topic #4 (0.100): 0.035*"osoba" + 0.028*"dnevnik" + 0.024*"nov" + 0.023*"očevid" + 0.023*"tijek" + 0.018*"napad" + 0.009*"putin" + 0.009*"hrvatski" + 0.007*"ukrajina" + 0.007*"nema"
# [INFO] 2022-11-07 07:29:00 gensim.models.ldamodel - topic diff=0.007416, rho=0.307977
# [INFO] 2022-11-07 07:29:00 gensim.models.ldamodel - -8.212 per-word bound, 296.4 perplexity estimate based on a held-out corpus of 1086 documents with 3864 words
# [INFO] 2022-11-07 07:29:01 gensim.utils - LdaMulticore lifecycle event {'msg': 'trained LdaMulticore<num_terms=1792, num_topics=10, decay=0.5, chunksize=2000> in 8.99s', 'datetime': '2022-11-07T07:29:01.133125', 'gensim': '4.2.0', 'python': '3.8.10 (default, Jun 22 2022, 20:18:18) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-124-generic-x86_64-with-glibc2.29', 'event': 'created'}
# [INFO] 2022-11-07 07:29:01 gensim.topic_coherence.probability_estimation - using ParallelWordOccurrenceAccumulator<processes=47, batch_size=64> to estimate probabilities from sliding windows
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - 47 accumulators retrieved from output queue
# [INFO] 2022-11-07 07:29:07 gensim.topic_coherence.text_analysis - accumulated word occurrence stats for 1086 virtual documents
# [INFO] 2022-11-07 07:29:08 gensim.models.ldamodel - using symmetric alpha at 0.09090909090909091
# [INFO] 2022-11-07 07:29:08 gensim.models.ldamodel - using symmetric eta at 0.09090909090909091
# [INFO] 2022-11-07 07:29:08 gensim.models.ldamodel - using serial LDA version on this node
# [INFO] 2022-11-07 07:29:08 gensim.models.ldamulticore - running online LDA training, 11 topics, 10 passes over the supplied corpus of 1086 documents, updating every 94000 documents, evaluating every ~1086 documents, iterating 50x with a convergence threshold of 0.001000
# [INFO] 2022-11-07 07:29:08 gensim.models.ldamulticore - training LDA model using 47 processes
# [INFO] 2022-11-07 07:29:14 gensim.models.ldamulticore - PROGRESS: pass 0, dispatched chunk #0 = documents up to #1086/1086, outstanding queue size 1
# [INFO] 2022-11-07 07:29:14 gensim.models.ldamodel - topic #3 (0.091): 0.033*"nov" + 0.024*"dnevnik" + 0.015*"TV" + 0.009*"godina" + 0.007*"vrata" + 0.007*"sat" + 0.007*"dan" + 0.007*"čovjek" + 0.006*"rad" + 0.006*"vijeće"
# [INFO] 2022-11-07 07:29:14 gensim.models.ldamodel - topic

# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - topic #3 (0.067): 0.044*"očevid" + 0.043*"tijek" + 0.020*"drama" + 0.010*"velik" + 0.010*"provjeriti" + 0.010*"vrijeme" + 0.007*"odluka" + 0.007*"zakon" + 0.007*"sabor" + 0.007*"dnevnik"
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - topic #2 (0.067): 0.033*"hrvatski" + 0.013*"velik" + 0.011*"dan" + 0.011*"modar" + 0.011*"čovjek" + 0.009*"sat" + 0.008*"dinamo" + 0.008*"hrvat" + 0.008*"predsjednik" + 0.008*"kuća"
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - topic diff=0.012474, rho=0.323711
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - -8.356 per-word bound, 327.5 perplexity estimate based on a held-out corpus of 1086 documents with 3864 words
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamulticore - PROGRESS: pass 9, dispatched chunk #0 = documents up to #1086/1086, outstanding queue size 1
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - topic #6 (0.067): 0.018*"hrvatski" + 0.012*"napad" + 0.009*"dan" + 0.009*"broj" + 0.009*"rast" + 0.009*"susret" + 0.009*"dijete" + 0.009*"treći" + 0.009*"posao" + 0.009*"posljedica"
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - topic #13 (0.067): 0.025*"dan" + 0.025*"problem" + 0.016*"dnevnik" + 0.015*"milijun" + 0.013*"godina" + 0.013*"sreća" + 0.010*"ozlijediti" + 0.008*"sat" + 0.008*"moguć" + 0.008*"topao"
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - topic #14 (0.067): 0.063*"osoba" + 0.017*"čovjek" + 0.015*"hrvatski" + 0.015*"kazna" + 0.011*"eksplozija" + 0.009*"putin" + 0.009*"godina" + 0.009*"zatvor" + 0.009*"ponuda" + 0.006*"dnevnik"
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - topic #4 (0.067): 0.067*"nov" + 0.055*"sat" + 0.040*"TV" + 0.025*"dnevnikučnova" + 0.021*"dnevnik" + 0.015*"velik" + 0.012*"dan" + 0.009*"novom-termin" + 0.009*"borba" + 0.009*"moderan"
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - topic #5 (0.067): 0.031*"velik" + 0.028*"dnevnik" + 0.023*"prosvjed" + 0.020*"napad" + 0.013*"zagreb" + 0.010*"hrvatski" + 0.009*"poskupljenje" + 0.008*"ruski" + 0.008*"odgovornost" + 0.008*"dolar"
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - topic diff=0.010227, rho=0.307977
# [INFO] 2022-11-07 07:30:21 gensim.models.ldamodel - -8.352 per-word bound, 326.7 perplexity estimate based on a held-out corpus of 1086 documents with 3864 words
# [INFO] 2022-11-07 07:30:22 gensim.utils - LdaMulticore lifecycle event {'msg': 'trained LdaMulticore<num_terms=1792, num_topics=15, decay=0.5, chunksize=2000> in 8.92s', 'datetime': '2022-11-07T07:30:22.295083', 'gensim': '4.2.0', 'python': '3.8.10 (default, Jun 22 2022, 20:18:18) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-124-generic-x86_64-with-glibc2.29', 'event': 'created'}
# [INFO] 2022-11-07 07:30:22 gensim.topic_coherence.probability_estimation - using ParallelWordOccurrenceAccumulator<processes=47, batch_size=64> to estimate probabilities from sliding windows
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - serializing accumulator to return to master...
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulator serialized
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - 47 accumulators retrieved from output queue
# [INFO] 2022-11-07 07:30:29 gensim.topic_coherence.text_analysis - accumulated word occurrence stats for 1086 virtual documents

# %%
from pprint import pprint
pprint(model_list[2].print_topics())
# Out:
# [INFO] 2022-11-07 07:40:26 gensim.models.ldamodel - topic
#   '0.021*"dnevnik" + 0.012*"istraga" + 0.010*"zemlja" + 0.010*"velik" + '
#   '0.009*"oružje" + 0.008*"poskupljenje"'),
#  (1,
#   '0.019*"prosvjed" + 0.014*"hrvatski" + 0.013*"predsjednik" + 0.011*"ruski" + '
#   '0.010*"snaga" + 0.009*"sumnja" + 0.009*"okolnost" + 0.009*"građanin" + '
#   '0.008*"ukrajinski" + 0.007*"euro"'),
#  (2,
#   '0.046*"osoba" + 0.029*"dan" + 0.014*"eksplozija" + 0.013*"dnevnik" + '
#   '0.013*"ukrajina" + 0.010*"hrvatski" + 0.009*"emisija" + '
#   '0.009*"gošća@dnevnik" + 0.009*"dobar" + 0.007*"godina"'),
#  (3,
#   '0.017*"čovjek" + 0.011*"hrvatski" + 0.008*"nov" + 0.006*"srbija" + '
#   '0.006*"život" + 0.006*"pravo" + 0.006*"svijet" + 0.006*"izborni" + '
#   '0.006*"suđenje" + 0.006*"visok"'),
#  (4,
#   '0.035*"velik" + 0.016*"nov" + 0.014*"dinamo" + 0.012*"ponuda" + '
#   '0.009*"pregovor" + 0.009*"razlog" + 0.009*"sindikat" + 0.009*"vježba" + '
#   '0.007*"dnevnik" + 0.007*"hrvat"'),
#  (5,
#   '0.035*"godina" + 0.022*"hrvatski" + 0.020*"nov" + 0.019*"dan" + '
#   '0.012*"život" + 0.010*"sat" + 0.009*"vlada" + 0.008*"prvi" + 0.008*"kazna" '
#   '+ 0.006*"predsjednik"'),
#  (6,
#   '0.020*"odluka" + 0.017*"nesreća" + 0.011*"putin" + 0.011*"rat" + '
#   '0.009*"ministar" + 0.009*"bivši" + 0.009*"liječnik" + 0.008*"drugi" + '
#   '0.007*"vlada" + 0.006*"europski"'),
#  (7,
#   '0.014*"dnevnik" + 0.014*"ozlijediti" + 0.011*"detalj" + 0.010*"sat" + '
#   '0.010*"dan" + 0.009*"požar" + 0.009*"sreća" + 0.009*"hrvatski" + '
#   '0.007*"inflacija" + 0.007*"situacija"'),
#  (8,
#   '0.053*"dnevnik" + 0.017*"građanin" + 0.013*"hrvatski" + 0.011*"policija" + '
#   '0.011*"reforma" + 0.010*"uprava" + 0.009*"nov" + 0.008*"modrić" + '
#   '0.008*"strah" + 0.008*"zdravstvo"'),
#  (9,
#   '0.062*"nov" + 0.013*"situacija" + 0.011*"velik" + 0.011*"premijer" + '
#   '0.010*"dnevnik" + 0.009*"sat" + 0.009*"rezultat" + 0.009*"teren" + '
#   '0.009*"plaća" + 0.009*"policija"'),
#  (10,
#   '0.026*"tijek" + 0.026*"očevid" + 0.024*"napad" + 0.014*"godina" + '
#   '0.010*"izbor" + 0.010*"težak" + 0.009*"hrvatski" + 0.008*"modar" + '
#   '0.008*"vrijeme" + 0.008*"velik"'),
#  (11,
#   '0.017*"cijena" + 0.012*"osoba" + 0.012*"dan" + 0.012*"uhititi" + '
#   '0.010*"velik" + 0.008*"hrvat" + 0.008*"topao" + 0.007*"mjesec" + '
#   '0.006*"ukrajina" + 0.005*"čovjek"')]
